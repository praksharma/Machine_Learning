# %% [markdown]
# # DGM (Deep Galerkin Method) for high-dimensional PDEs
#
# * for high dimensional PDEs
# * meshfree
#
# The method is similar in spirit to the Galerkin method, but with several key changes using ideas from machine learning. The deep learning algorithm, or “Deep Galerkin Method” (DGM), uses a deep neural network instead
# of a linear combination of basis functions.
#
# Consider the following nonlinear PDE.
#
# ![image.png](attachment:d7ff87a2-b20d-4b82-a75f-76ab3b478b56.png)
#
# where $\partial \Omega$ is the boundary of the domain $\Omega$. The loss function is as follows:
#
# ![image.png](attachment:fdbfbabc-e559-44d3-bb60-a5f21faba128.png)
#
# or
#
# ![image.png](attachment:7d9b9fcc-e732-4d56-ae22-ddd67c6c8dc9.png)
#
# The first term is the PDE loss, the second term is the BC loss and the third term is the IC loss.

# %% [markdown]
# # Algorithm
# The DGM algorithm is:
#
# * Generate random points according to respective probability densities
# * Calculate the training loss.
# * Take a descent step using SGD at the random point.
# * Repeat until convergence criterion is satisﬁed.
#
# # A Monte Carlo method for fast computation of second derivatives
#
# Not very useful.
#
# # DGM architecture
# In the PDE applications in this paper, we found that a neural network architecture similar in spirit to that of LSTM networks improved performance. DGM arch is used by the Nivida Modulus as well because it is useful for predicting discontinuous solution.
#
# ![image.png](attachment:42329941-1a47-4a53-8dde-7bc191528379.png)
#
# ![image.png](attachment:994ea415-60b1-46f8-89ea-676efb441781.png)

# %% [markdown]
# # Visualising the architecture
# It consist of three DGM layers: an input, hidden and output layer as follows.
#
# ![image.png](attachment:9989988d-fa28-417c-b8ad-2fb1bee93190.png)

# %% [markdown]
# here $x$ is the spatio-temnporal sampling. $S^1$ is the activated neuron. Thye inside of a DGM layer is as follows:
#
# ![image.png](attachment:22a0c756-6891-4365-8143-a8b589df7a24.png)

# %% [markdown]
# Number of parameters in a DGM layer is 8 times that of a Dense layer.
